# %% [markdown]
# # Libraries Installation

# %%
# !pip install yfinance -q
# !pip install matplotlib -q
# Out:
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.0.1 -> 23.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# %% [markdown]
# # Selection of portfolio stocks

# %%
stocks = ["AAPL", "MSFT", "PETR4.SA", "VALE3.SA"]

# %% [markdown]
# # Import financial assets data

# %%
stocks_data = yf.download(stocks, start="2020-01-01")
# Out:
# [*********************100%***********************]  4 of 4 completed

# %%
stocks_data["Adj Close"]
# Out:
#                   AAPL        MSFT   PETR4.SA   VALE3.SA
# Date
# 2020-01-02   73.347954  155.422043  12.180104  39.578945
# 2020-01-03   72.634857  153.486740  12.080917  39.287544
# 2020-01-06   73.213608  153.883499  12.223745  39.054432
# 2020-01-07   72.869293  152.480438  12.176136  39.338539
# 2020-01-08   74.041489  154.909210  12.100755  39.345825
# ...                ...         ...        ...        ...
# 2023-08-02  192.580002  327.500000  30.530001  67.089996
# 2023-08-03  191.169998  326.660004  30.920000  67.510002
# 2023-08-04  181.990005  327.779999  30.000000  67.559998
# 2023-08-07  178.850006  330.109985        NaN        NaN
# 2023-08-08  179.320007  324.500000  30.200001  67.000000
#
# [929 rows x 4 columns]

# %%
stocks_data["Adj Close"].plot()

plt.title("Stock tracker")
plt.xlabel("Date")
plt.ylabel("Adjusted price")
plt.legend(fontsize=7);

# %% [markdown]
# # Price normalization (data scaling)

# %%
normalized_data = stocks_data["Adj Close"] / stocks_data["Adj Close"].iloc[0]

# %%
normalized_data.plot()

plt.title("Stock Tracker (normalized)")
plt.xlabel("Date")
plt.ylabel("Ajusted price")
plt.legend(fontsize=7);
